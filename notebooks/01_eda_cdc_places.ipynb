# %% [markdown]
# # SustAInable — Phase 2 Data Exploration
# **Dataset:** CDC PLACES — Local Data for Better Health
# **Goal:** Understand chronic disease burden and disability prevalence at ZIP code level before modeling.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# CDC PLACES data — publicly available at data.cdc.gov
# Full URL: https://data.cdc.gov/500-Cities-Places/PLACES-Local-Data-for-Better-Health-ZCTA-Data-2023/qnzd-25i4
print('Libraries loaded. Ready to pull CDC PLACES data.')
